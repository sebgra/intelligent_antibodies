# %%
import pandas as pd

# %%
df_seq = pd.read_csv("../data/SAbDab/sequences.csv", sep=";")
df_seq[["seq_rcpb", "seq_type"]] = df_seq["seq_id"].str.split('|',  n=1, expand=True)
df_ab = df_seq[df_seq["seq_type"] == "ab"]

# %%
df_ab["sequence"].str.len().mean()
# Out:
# 213.3815789473684

# %%
df_ab["sequence"].str.len().median()
# Out:
# 218.0

# %%
lengths = df_ab["sequence"].str.len()

# %%
import seaborn as sns

# %%
sns.histplot(lengths)
# Out:
# <Axes: xlabel='sequence', ylabel='Count'>

# %%
df_ag = df_seq[df_seq["seq_type"] == "ag"]

# %%
lengths_ag = df_ag["sequence"].str.len()

# %%
sns.histplot(lengths_ag)
# Out:
# <Axes: xlabel='sequence', ylabel='Count'>

# %%
lengths_ag
# Out:
# 0       469
# 1       143
# 8       149
# 9       278
# 12      222
#        ...
# 3024    222
# 3025    278
# 3026    222
# 3027    246
# 3032    152
# Name: sequence, Length: 1437, dtype: int64
